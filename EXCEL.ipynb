# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
read = pd.read_excel('C:\Excel\practice.xlsx')
read.head()
readNew = read[['High','Low']]
plt.plot(readNew)
readNew.head()
# Out:
#    High   Low
# 0  1000   500
# 1  2000   800
# 2  3000  1200
# 3  4000  1500
# 4  5000   900
