# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
print(x)
# Out:
# [6.02676843 6.46949968 4.13379425 7.36204748 4.76496407 3.97235964
#  5.47816789 4.43866095 4.4672406  4.45048023 3.09562478 6.10224613
#  4.41114961 4.52652769 5.04992357 3.66303876 5.71896745 5.5967644
#  3.91620385 4.32464081 4.04627331 4.33468273 3.84231555 5.35284489
#  3.30423084 6.51790618 4.93452834 6.29188652 4.74617718 4.71361038
#  4.96587063 5.30502456 6.72322668 6.42367338 4.21454774 5.47169763
#  7.14985403 5.22390942 5.69888506 6.75383861 5.3969017  5.69441112
#  6.19131527 5.11840712 4.52033349 6.83839295 4.93253665 5.60178009
#  6.10913386 3.92914885 5.32407958 3.35543056 3.66122617 6.11513199
#  5.10303691 6.82889576 5.07921236 5.11914168 4.62587781 3.372525
#  3.86372772 3.19219783 4.51679716 3.75256932 5.75753034 5.35286864
#  5.6850269  4.27565504 6.35893272 5.11685135 4.05931595 5.98703623
#  4.94749745 4.24712265 4.77576853 5.13074712 5.97776112 4.20183523
#  4.76867425 3.67983495 4.1987618  5.13114499 5.23520357 4.5818863
# ...
